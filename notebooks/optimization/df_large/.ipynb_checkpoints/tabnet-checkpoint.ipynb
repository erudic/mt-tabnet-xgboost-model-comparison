# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from model_trainer.trainers.tabnet_trainer import TabNetTrainer
from fastai.tabular.all import *

# %%
df = pd.read_csv('../../../data/dataset_initial.csv')
df['Weather_Condition_Arr'] = df['Weather_Condition_Arr'].apply(lambda x: literal_eval(x) if str(x)!='nan' else x)
X, y = df[df.columns.drop('Severity')], df['Severity']

# %%
X_train_val_test, Y_train_val_test = X.copy(),y.copy()
X_train_val,X_val,Y_train_val,Y_val = train_test_split(X_train_val_test, Y_train_val_test,train_size=0.8,stratify=Y_train_val_test)

# %%
from hyperopt import STATUS_OK,hp,tpe,Trials,fmin
from hyperopt.pyll import scope

tabnet_large_space={
    "lookahead": hp.choice("lookahead",[False,True]),
    "optimizer": hp.choice('optimizer',[
        {
            "opttype":"Adam",
             "wd":hp.loguniform('wdadam', np.log(0.0001), np.log(0.3))
        },
        {
            "opttype":"SGD",
            "wd":hp.loguniform('wdsgd', np.log(0.0001), np.log(0.3))
        },
        {
            "opttype":"RAdam",
            "wd":hp.loguniform('wdradam', np.log(0.0001), np.log(0.3))
        }
    ]),
    "n":scope.int(hp.choice("n",[8,32,64])),
    "n_steps":scope.int(hp.quniform("n_steps",3,10,1)),
    "gamma":hp.uniform("gamma",1,2),
    "momentum":hp.uniform("momentum",0,1),
    "lr":hp.choice("lr",[0.005,0.01,0.02,0.025]),
    "batch_size":hp.quniform("batch_size",12,15,1),
    "virtual_batch_size":hp.quniform("virtual_batch_size",8,11,1)
    }

# %%
def get_optimizer(opttype,opt_params,lookahead):
    OPT_DICT = {
        "Adam":Adam,
        "RAdam":RAdam,
        "SGD":SGD
    }
    opt_constructor = OPT_DICT[opttype]
    if lookahead:
        partial_opt = lambda spliter,lr: Lookahead(opt_constructor(spliter,lr,**opt_params))
        optimizer = partial_opt
    else:
        optimizer = partial(opt_constructor,**opt_params)
    return optimizer

def process_params(params):
    params['batch_size'] = int(np.power(2,params['batch_size']))
    params['virtual_batch_size'] = int(np.power(2,params['virtual_batch_size']))

    opt_params = params.pop('optimizer')
    opttype = opt_params.pop('opttype')
    lookahead = params.pop('lookahead')
    optimizer = get_optimizer(opttype,opt_params,lookahead)
    
    params['optimizer'] = optimizer
    n=params.pop('n')
    params['n_d']=n
    params['n_a']=n
    return params

# %% [markdown]
# Dumping trial object after each evaluation to preserve the state.

# %%
import os.path
from os import path


def tabnet_fn(params):
    print(params)
    params = process_params(params)
    tabnet_trainer = TabNetTrainer(X_train_val,Y_train_val,vtype="hold-out",split=0.8,epochs=50)
    return -tabnet_trainer.train_and_validate(params)
    
    
if path.exists("tabnet-trials.p"):
    trials = pickle.load(open("tabnet-trials.p",'rb'))
else:
    trials = Trials()   

best_hyperparams = fmin(fn = tabnet_fn,
                        space = tabnet_large_space,
                        algo = tpe.suggest,
                        max_evals = 20,
                        trials = trials)

pickle.dump(trials, open("tabnet-trials.p", "wb"))
# Out:
# {'batch_size': 14.0, 'gamma': 1.9640432533357484, 'lookahead': False, 'lr': 0.01, 'momentum': 0.043221768603385, 'n': 32, 'n_steps': 9, 'optimizer': {'opttype': 'SGD', 'wd': 0.12220694478623302}, 'virtual_batch_size': 10.0}
#  95%|█████████▌| 19/20 [00:00<?, ?trial/s, best loss=?]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.664033</td>
#       <td>24.807894</td>
#       <td>-0.015009</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.966212</td>
#       <td>12.612677</td>
#       <td>-0.012697</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.422606</td>
#       <td>4.101699</td>
#       <td>0.009712</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.147711</td>
#       <td>1.861348</td>
#       <td>0.009727</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.788718</td>
#       <td>1.805862</td>
#       <td>0.026437</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.589476</td>
#       <td>4.115658</td>
#       <td>-0.005573</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.473553</td>
#       <td>4.355977</td>
#       <td>0.000358</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.403453</td>
#       <td>15.442947</td>
#       <td>0.086371</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.380529</td>
#       <td>163.429672</td>
#       <td>0.022184</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.299873</td>
#       <td>6.202958</td>
#       <td>-0.100671</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.287610</td>
#       <td>4.976592</td>
#       <td>-0.056675</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.253856</td>
#       <td>1.693743</td>
#       <td>-0.004673</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.232224</td>
#       <td>8.237363</td>
#       <td>-0.114151</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.220289</td>
#       <td>12.157015</td>
#       <td>-0.037141</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.216859</td>
#       <td>4.694614</td>
#       <td>-0.024156</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.211739</td>
#       <td>4.566098</td>
#       <td>-0.037043</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.207572</td>
#       <td>1.658141</td>
#       <td>0.000152</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.207031</td>
#       <td>1.962830</td>
#       <td>0.040289</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.204845</td>
#       <td>1.848367</td>
#       <td>0.004837</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.204640</td>
#       <td>23.859758</td>
#       <td>0.019081</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.205791</td>
#       <td>1.388493</td>
#       <td>-0.024493</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.203647</td>
#       <td>2.419574</td>
#       <td>-0.000400</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.200763</td>
#       <td>1.956354</td>
#       <td>-0.026098</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.197661</td>
#       <td>1.846663</td>
#       <td>-0.005319</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.196087</td>
#       <td>1.950264</td>
#       <td>0.002323</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.191117</td>
#       <td>2.747004</td>
#       <td>0.012810</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.186486</td>
#       <td>1.467687</td>
#       <td>0.008882</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.185316</td>
#       <td>1.320100</td>
#       <td>0.049521</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.181791</td>
#       <td>1.327422</td>
#       <td>0.020993</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.177962</td>
#       <td>1.542238</td>
#       <td>0.016326</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.177918</td>
#       <td>1.610455</td>
#       <td>0.061854</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.173198</td>
#       <td>9.820060</td>
#       <td>0.005246</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.172313</td>
#       <td>7.495865</td>
#       <td>0.005671</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.228261</td>
#       <td>1.478066</td>
#       <td>0.027143</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.194924</td>
#       <td>1.485158</td>
#       <td>0.025291</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.183488</td>
#       <td>1.302255</td>
#       <td>0.076161</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.177913</td>
#       <td>1.285759</td>
#       <td>0.077430</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.214075</td>
#       <td>1.350066</td>
#       <td>0.050195</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.210990</td>
#       <td>1.508769</td>
#       <td>0.019265</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.187337</td>
#       <td>1.434491</td>
#       <td>0.037207</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.189936</td>
#       <td>1.748433</td>
#       <td>0.036545</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.188072</td>
#       <td>1.341063</td>
#       <td>0.035295</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.169640</td>
#       <td>1.166325</td>
#       <td>0.117561</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.166358</td>
#       <td>1.167753</td>
#       <td>0.120259</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.167594</td>
#       <td>1.175083</td>
#       <td>0.119933</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.163734</td>
#       <td>1.168839</td>
#       <td>0.118370</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.167635</td>
#       <td>1.188415</td>
#       <td>0.127133</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.167293</td>
#       <td>1.170554</td>
#       <td>0.122371</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.166809</td>
#       <td>1.170667</td>
#       <td>0.122058</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.166359</td>
#       <td>1.169588</td>
#       <td>0.122671</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>
# 100%|██████████| 20/20 [1:14:16<00:00, 4456.57s/trial, best loss: -0.2569755410042381]

# %%
very_good_params={'batch_size': 13.0, 'gamma': 1.0087052714830005, 'lookahead': True, 'lr': 0.01, 'momentum': 0.9091942469111192, 'n': 64, 'n_steps': 6, 'optimizer': {'opttype': 'Adam', 'wd': 0.08995302324325974}, 'virtual_batch_size': 9.0}

# %%
also_good_params={'batch_size': 12.0, 'gamma': 1.7939830971543138, 'lookahead': True, 'lr': 0.025, 'momentum': 0.21616516545401665, 'n': 8, 'n_steps': 7, 'optimizer': {'opttype': 'Adam', 'wd': 0.018052913292329078}, 'virtual_batch_size': 8.0}

# %%
best_hyperparams
# Out:
# {'batch_size': 12.0,
#  'gamma': 1.7939830971543138,
#  'lookahead': 1,
#  'lr': 3,
#  'momentum': 0.21616516545401665,
#  'n': 0,
#  'n_steps': 7.0,
#  'optimizer': 0,
#  'virtual_batch_size': 8.0,
#  'wdadam': 0.018052913292329078}

# %%
also_also_good_params={'batch_size': 13.0, 'gamma': 1.8945905111689254, 'lookahead': True, 'lr': 0.02, 'momentum': 0.8441591372924436, 'n': 64, 'n_steps': 7, 'optimizer': {'opttype': 'RAdam', 'wd': 0.0024663711835345332},virtual_batch_size="oko 10"}
# Out:
#   File "/tmp/ipykernel_182/1119216785.py", line 1
#     also_also_good_params={'batch_size': 13.0, 'gamma': 1.8945905111689254, 'lookahead': True, 'lr': 0.02, 'momentum': 0.8441591372924436, 'n': 64, 'n_steps': 7, 'optimizer': {'opttype': 'RAdam', 'wd': 0.0024663711835345332}
#                                                                                                                                                                                                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
best_hyperparams
# Out:
# {'batch_size': 12.0,
#  'gamma': 1.7939830971543138,
#  'lookahead': 1,
#  'lr': 3,
#  'momentum': 0.21616516545401665,
#  'n': 0,
#  'n_steps': 7.0,
#  'optimizer': 0,
#  'virtual_batch_size': 8.0,
#  'wdadam': 0.018052913292329078}

# %%
from hyperopt import space_eval

space_eval(tabnet_large_space,best_hyperparam)
# Out:
# {'batch_size': 12.0,
#  'gamma': 1.7939830971543138,
#  'lookahead': True,
#  'lr': 0.025,
#  'momentum': 0.21616516545401665,
#  'n': 8,
#  'n_steps': 7,
#  'optimizer': {'opttype': 'Adam', 'wd': 0.018052913292329078},
#  'virtual_batch_size': 8.0}

# %%
trials.argmin
# Out:
# {'batch_size': 12.0,
#  'gamma': 1.7939830971543138,
#  'lookahead': 1,
#  'lr': 3,
#  'momentum': 0.21616516545401665,
#  'n': 0,
#  'n_steps': 7.0,
#  'optimizer': 0,
#  'virtual_batch_size': 8.0,
#  'wdadam': 0.018052913292329078}

# %%
if path.exists("tabnet-trials.p"):
    trials = pickle.load(open("tabnet-trials.p",'rb'))
else:
    trials = Trials()   


params = space_eval(tabnet_large_space,trails.argmin)
params = process_params(params)
tt = TabNetTrainer(X_train_val,Y_train_val,vtype="hold-out",split=0.8,epochs=50)

model = tt._train_model(params,tt.X_train,tt.y_train,tt.X_val,tt.Y_val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_172/3685139629.py in <module>
#       3 tt = TabNetTrainer(X_train_val,Y_train_val,vtype="hold-out",split=0.8,epochs=50)
#       4
# ----> 5 model = tt._train_model(params,tt.X_train,tt.y_train,tt.X_val,tt.Y_val)
#       6
#
# AttributeError: 'TabNetTrainer' object has no attribute 'y_train'
