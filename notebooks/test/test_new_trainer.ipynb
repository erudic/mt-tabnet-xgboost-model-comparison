# %%
from model_trainer.data.hold_out_data_box import HoldOutDataBox
from model_trainer.tabnet.tabnet_trainer import TabNetTrainer
from model_trainer.xgboost.xgboost_trainer import XGBoostTrainer
from model_trainer.tabnet.utils import get_optimizer_from_params
from model_trainer.data import data_loader
from model_trainer import config

# %%
X_train_val, Y_train_val = data_loader.load('large')
db = HoldOutDataBox(X_train_val,Y_train_val,cat_vars=config.categorical_variables,split=0.75)
X_train,Y_train,X_val,Y_val = db.get_processed_data()

# %%
X_train
# Out:
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 1655338  33.618720 -111.891460  33.561750 -111.883530         3.963
# 1984079  34.426270 -118.585063  34.419340 -118.581413         0.522
# 1027189  32.697211  -96.823121  32.703361  -96.825401         0.445
# 1223876  40.798955  -73.482257  40.798846  -73.481437         0.044
# 2053497  40.411700  -74.141640  40.411700  -74.141640         0.000
# ...            ...         ...        ...         ...           ...
# 1004224  32.768840  -96.807680  32.768840  -96.807680         0.000
# 1195911  33.279874  -81.030167  33.285428  -81.030927         0.386
# 2248738  25.855368  -80.209387  25.861831  -80.209110         0.447
# 1321139  45.593879 -118.478670  45.600099 -118.502926         1.249
# 1847183  26.509303  -80.073778  26.470968  -80.089268         2.817
#
#          Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 1655338            75.0            NaN         34.0         30.02
# 1984079            76.0           76.0         52.0         29.03
# 1027189            74.0           74.0         53.0         29.30
# 1223876            63.0           63.0         52.0         29.93
# 2053497            83.0           83.0         46.0         29.75
# ...                 ...            ...          ...           ...
# 1004224            86.0           86.0         53.0         29.46
# 1195911            30.0           30.0         82.0         29.75
# 2248738            87.0           87.0         63.0         29.97
# 1321139            35.0           22.0         85.0         28.52
# 1847183            72.0           72.0         59.0         30.13
#
#          Visibility(mi)  ...  Cloudy  Fair  Fog  Light Rain  Light Snow  \
# 1655338            10.0  ...       0     0    0           0           0
# 1984079            10.0  ...       0     1    0           0           0
# 1027189            10.0  ...       0     1    0           0           0
# 1223876            10.0  ...       0     1    0           0           0
# 2053497            10.0  ...       0     1    0           0           0
# ...                 ...  ...     ...   ...  ...         ...         ...
# 1004224            10.0  ...       0     1    0           0           0
# 1195911            10.0  ...       0     1    0           0           0
# 2248738            10.0  ...       0     0    0           0           0
# 1321139            10.0  ...       0     1    0           0           0
# 1847183            10.0  ...       0     1    0           0           0
#
#          Mostly Cloudy  Overcast  Partly Cloudy  Scattered Clouds  \
# 1655338              1         0              0                 0
# 1984079              0         0              0                 0
# 1027189              0         0              0                 0
# 1223876              0         0              0                 0
# 2053497              0         0              0                 0
# ...                ...       ...            ...               ...
# 1004224              0         0              0                 0
# 1195911              0         0              0                 0
# 2248738              0         0              1                 0
# 1321139              0         0              0                 0
# 1847183              0         0              0                 0
#
#          Weather_Other
# 1655338              0
# 1984079              0
# 1027189              0
# 1223876              0
# 2053497              0
# ...                ...
# 1004224              0
# 1195911              0
# 2248738              0
# 1321139              0
# 1847183              0
#
# [569068 rows x 52 columns]

# %%
Y_train
# Out:
# 1655338    1
# 1984079    1
# 1027189    1
# 1223876    1
# 2053497    2
#           ..
# 1004224    2
# 1195911    1
# 2248738    1
# 1321139    1
# 1847183    1
# Name: Severity, Length: 569068, dtype: int64

# %%
opt = get_optimizer_from_params("Adam",{"wd":0.01,"lr":0.01},False)

# %%
from fastai.tabular.all import EarlyStoppingCallback, SaveModelCallback
callbacks = [
    EarlyStoppingCallback (
        monitor='valid_loss', 
        patience=10,
        reset_on_fit=True
    ),
    SaveModelCallback (
        monitor='matthews_corrcoef',
        fname='model',
        at_end=False,
        with_opt=True,
        reset_on_fit=True
    )
]

# %%
#tt = TabNetTrainer({},opt,batch_size=4096,cbs=callbacks,class_weights=None)

# %%
#learner, metric = tt.train_and_validate(X_train,X_val,Y_train,Y_val,epochs=2)

# %%
#learner.validate()[1]

# %%
xt = XGBoostTrainer(dict())
model = xt.train(X_train,Y_train)

# %%
help(xt.validate)
# Out:
# Help on method validate in module model_trainer.xgboost.xgboost_trainer:
#
# validate(model, X_val, Y_val) method of model_trainer.xgboost.xgboost_trainer.XGBoostTrainer instance
